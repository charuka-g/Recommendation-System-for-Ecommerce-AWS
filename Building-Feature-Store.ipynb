# %%
# pip install "sagemaker==2.*" boto3 pandas
# Out:
# Requirement already satisfied: sagemaker==2.* in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (2.255.0)
# Requirement already satisfied: boto3 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (1.42.14)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: attrs<26,>=24 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (25.4.0)
# Requirement already satisfied: cloudpickle>=2.2.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (3.1.2)
# Requirement already satisfied: docker in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (7.1.0)
# Requirement already satisfied: fastapi in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (0.125.0)
# Requirement already satisfied: google-pasta in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (0.2.0)
# Requirement already satisfied: graphene<4,>=3 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (3.4.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (6.11.0)
# Requirement already satisfied: jsonschema in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (4.25.0)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (2.3.5)
# Requirement already satisfied: omegaconf<3,>=2.2 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (2.3.0)
# Requirement already satisfied: packaging<25,>=23.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (24.2)
# Requirement already satisfied: pathos in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (0.3.4)
# Requirement already satisfied: platformdirs in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (4.5.0)
# Requirement already satisfied: protobuf<6.32,>=3.12 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (4.25.8)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (7.0.0)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (6.0.3)
# Requirement already satisfied: requests in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (2.32.5)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.71 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (1.0.72)
# Requirement already satisfied: schema in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (0.7.8)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (3.2.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (4.67.1)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (2.6.1)
# Requirement already satisfied: uvicorn in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker==2.*) (0.38.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.14 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from boto3) (1.42.14)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.14->boto3) (2.9.0.post0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker==2.*) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker==2.*) (3.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.7.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker==2.*) (4.15.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker==2.*) (3.23.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from omegaconf<3,>=2.2->sagemaker==2.*) (4.9.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.14->boto3) (1.17.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (2.12.5)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from jsonschema->sagemaker==2.*) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from jsonschema->sagemaker==2.*) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from jsonschema->sagemaker==2.*) (0.28.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (2.19.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.71->sagemaker==2.*) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from requests->sagemaker==2.*) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from requests->sagemaker==2.*) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from requests->sagemaker==2.*) (2025.11.12)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from fastapi->sagemaker==2.*) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from fastapi->sagemaker==2.*) (0.0.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi->sagemaker==2.*) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi->sagemaker==2.*) (1.3.1)
# Requirement already satisfied: ppft>=1.7.7 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pathos->sagemaker==2.*) (1.7.7)
# Requirement already satisfied: dill>=0.4.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pathos->sagemaker==2.*) (0.4.0)
# Requirement already satisfied: pox>=0.3.6 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pathos->sagemaker==2.*) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.18 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from pathos->sagemaker==2.*) (0.70.18)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from uvicorn->sagemaker==2.*) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages (from uvicorn->sagemaker==2.*) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import sagemaker

print("Python ok")
print("sagemaker:", sagemaker.__version__)

boto_sess = boto3.Session()  # uses your local AWS creds/SSO
sm_session = sagemaker.Session(boto_session=boto_sess)

print("Region:", boto_sess.region_name)
print("Default bucket:", sm_session.default_bucket())
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/charukagunawardhane/Library/Application Support/sagemaker/config.yaml
# Python ok
# sagemaker: 2.255.0
# Region: ap-south-1
# Default bucket: sagemaker-ap-south-1-487512486150

# %% [markdown]
# ## Local Notebook Initialization Code

# %%
# 1. Configuration
region = "ap-south-1" # Change to your region
# role_arn = "arn:aws:iam::487512486150:user/aws-admin-charuka" # Paste your ARN here
role_arn = "arn:aws:iam::487512486150:role/recommendationsystem-sagemaker-role"

# 2. Initialize Boto3 Session with your local credentials
boto_session = boto3.Session(region_name=region)

# 3. Create SageMaker Session
sagemaker_session = sagemaker.Session(
    boto_session=boto_session,
    default_bucket="amazon-sagemaker-local-dev-store"
)

# 4. Initialize Feature Store Runtime Clients
featurestore_runtime = boto_session.client(
    service_name='sagemaker-featurestore-runtime', 
    region_name=region
)
sagemaker_client = boto_session.client(
    service_name='sagemaker', 
    region_name=region
)

print(f"Connected locally to SageMaker in {region}")
# Out:
# Connected locally to SageMaker in ap-south-1

# %%
 # List all feature groups in your region
response = sagemaker_client.list_feature_groups()

print("Available Feature Groups:")
for fg in response['FeatureGroupSummaries']:
    print(f"- {fg['FeatureGroupName']} (Created: {fg['CreationTime']})")
# Out:
# Available Feature Groups:
# - all-beauty-features-1766218384 (Created: 2025-12-20 14:06:25.712000+05:30)

# %% [markdown]
# ## Define and Create (Local Execution)

# %%
import boto3
from sagemaker.feature_store.feature_group import FeatureGroup
import time
import pandas as pd

# %%
s3 = boto3.client("s3")
s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': 'J4SM0C0JHXN0SM6W',
#   'HostId': 'NBC/AivwVPEEyB3e/lxgo9p3M3+JvL6v0mhAGnD2sc9ukBuMiMItZQSz9ZpqL/uOn2ttjSU5c/g=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'NBC/AivwVPEEyB3e/lxgo9p3M3+JvL6v0mhAGnD2sc9ukBuMiMItZQSz9ZpqL/uOn2ttjSU5c/g=',
#    'x-amz-request-id': 'J4SM0C0JHXN0SM6W',
#    'date': 'Sat, 20 Dec 2025 20:32:12 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'amazon-sagemaker-487512486150-ap-south-1-4923573543c7',
#    'CreationDate': datetime.datetime(2025, 12, 20, 2, 59, 53, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::amazon-sagemaker-487512486150-ap-south-1-4923573543c7'},
#   {'Name': 'aws-glue-assets-487512486150-ap-south-1',
#    'CreationDate': datetime.datetime(2025, 12, 19, 12, 50, 52, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::aws-glue-assets-487512486150-ap-south-1'},
#   {'Name': 'recommendation-project-rapid',
#    'CreationDate': datetime.datetime(2025, 12, 18, 13, 32, 53, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::recommendation-project-rapid'},
#   {'Name': 'sagemaker-ap-south-1-487512486150',
#    'CreationDate': datetime.datetime(2025, 12, 20, 5, 25, 2, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::sagemaker-ap-south-1-487512486150'}],
#  'Owner': {'ID': 'e63e5b895a10ec7854ab7b36b0893204139580eb71ea0f7d53a784d3894b26f2'}}

# %%
# Unique name for All_Beauty
feature_group_name = f"all-beauty-features-{int(time.time())}"

all_beauty_fg = FeatureGroup(
    name=feature_group_name, 
    sagemaker_session=sagemaker_session
)

# %%
df = pd.read_parquet(
    "s3://recommendation-project-rapid/processed/all_beauty_dataset",
    engine="pyarrow"
)

df.head()
# Out:
#                         user_id parent_asin  event_time_seconds calendar_date  \
# 0  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  B09JS339BZ        1.643394e+09    2022-01-28
# 1  AHGAOIZVODNHYMNCBV4DECZH42UQ  B01AKTGHFW        1.500769e+09    2017-07-23
# 2  AFZUK3MTBIBEDQOPAK3OATUOUKLA  B0BFR5WF1R        1.675826e+09    2023-02-08
# 3  AFETVW7S5M4LVJ7GTWPCKT7S3YBQ  B01M5KNSQN        1.649634e+09    2022-04-10
# 4  AGVVUU3QRQBHNASSGI5YQLPYOI2Q  B09FF97RHL        1.648825e+09    2022-04-01
#
#                                          movie_title main_category rating
# 0  muaowig Ombre Body Wave Bundles 1B Grey Human ...    All Beauty    1.0
# 1  Charcoal Konjac Face Sponge 3 pk | Acne, Psori...    All Beauty    1.0
# 2  Halo Hair Extensions Thick Invisible Wire Hair...    All Beauty    1.0
# 3                        NYX Eyebrow Shaper, 1 Count    All Beauty    1.0
# 4  24 Eyebrow stencil , Meilala Eyebrow Shaper Ki...    All Beauty    1.0

# %%
df['rating'] = df['rating'].astype('float64')

# %%
# # After loading your cleaned Parquet data into a Pandas DataFrame 'df'
# all_beauty_fg.load_feature_definitions(data_frame=df)
# print("Complete loading feature definitions")
# print("")
# Out:
# Complete loading feature definitions

# %%
# Create the group in the cloud from your local notebook
all_beauty_fg.create(
    s3_uri="s3://recommendation-project-rapid/offline-store",
    record_identifier_name="user_id",
    event_time_feature_name="event_time_seconds",
    role_arn=role_arn,
    enable_online_store=True
)

print("Complete creating feature groups")
print("")
# Out:
# Complete creating feature groups

# %%
# import time

def wait_for_feature_group_creation(feature_group):
    status = feature_group.describe().get("FeatureGroupStatus")
    print(f"Initial status for {feature_group.name}: {status}")
    
    while status == "Creating":
        print("Waiting for Feature Group to be Created...")
        time.sleep(10)  # Wait 10 seconds before checking again
        status = feature_group.describe().get("FeatureGroupStatus")
        
    if status == "Created":
        print(f"Feature Group {feature_group.name} successfully created!")
    else:
        # If it's 'CreateFailed', SageMaker will provide a reason
        description = feature_group.describe()
        failure_reason = description.get("FailureReason", "Unknown failure.")
        print(f"Feature Group creation failed. Status: {status}")
        print(f"Reason: {failure_reason}")

# Run this for your specific group
wait_for_feature_group_creation(all_beauty_fg)
# Out:
# Initial status for all-beauty-features-1766218384: Created
# Feature Group all-beauty-features-1766218384 successfully created!

# %% [markdown]
# ## Ingest Data

# %%
from sagemaker.feature_store.feature_group import FeatureGroup

# 1. Use the EXACT name of the group you created earlier 
# (Check the SageMaker Console or Unified Studio if you forgot the exact string)
existing_fg_name = "all-beauty-features-1766218384" 

# 2. Re-instantiate the object
loaded_fg = FeatureGroup(name=existing_fg_name, sagemaker_session=sagemaker_session)

# 3. Verify it's connected by describing it
try:
    description = loaded_fg.describe()
    print(f"Successfully loaded Feature Group: {existing_fg_name}")
    print(f"Status: {description.get('FeatureGroupStatus')}")
except Exception as e:
    print(f"Error: Could not find Feature Group '{existing_fg_name}'. Details: {e}")
# Out:
# Successfully loaded Feature Group: all-beauty-features-1766218384
# Status: Created

# %%
# Ingest the cleaned Pandas DataFrame 'df'
# max_workers=5 allows parallel threads for faster upload from your local machine
loaded_fg.ingest(data_frame=df, max_workers=5, wait=True)

print("Ingestion complete.")
# Out:
# Ingestion complete.

# %% [markdown]
# ## Creating Separate Feature Groups

# %%
# --- CREATE USER FEATURE GROUP ---
user_fg_name = f"all-beauty-users-{int(time.time())}"
user_fg = FeatureGroup(name=user_fg_name, sagemaker_session=sagemaker_session)

# Load only the columns related to the user
user_cols = ['user_id', 'event_time_seconds', 'rating_count_by_user'] # example user columns
user_fg.load_feature_definitions(data_frame=df[user_cols])

user_fg.create(
    s3_uri="s3://recommendation-project-rapid/offline-store/users",
    record_identifier_name="user_id",
    event_time_feature_name="event_time_seconds",
    role_arn=role_arn,
    enable_online_store=True
)

# --- CREATE ITEM FEATURE GROUP ---
item_fg_name = f"all-beauty-items-{int(time.time())}"
item_fg = FeatureGroup(name=item_fg_name, sagemaker_session=sagemaker_session)

# Load only the columns related to the item/product
item_cols = ['parent_asin', 'event_time_seconds', 'average_rating', 'main_category']
item_fg.load_feature_definitions(data_frame=df[item_cols])

item_fg.create(
    s3_uri="s3://recommendation-project-rapid/offline-store/items",
    record_identifier_name="parent_asin",
    event_time_feature_name="event_time_seconds",
    role_arn=role_arn,
    enable_online_store=True
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │    4                                                                                             │
# │    5 # Load only the columns related to the user                                                 │
# │    6 user_cols = ['user_id', 'event_time_seconds', 'rating_count_by_user'] # example user col    │
# │ ❱  7 user_fg.load_feature_definitions(data_frame=df[user_cols])                                  │
# │    8                                                                                             │
# │    9 user_fg.create(                                                                             │
# │   10 │   s3_uri="s3://recommendation-project-rapid/offline-store/users",                         │
# │                                                                                                  │
# │ /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages/pandas/core/frame.py:4 │
# │ 119 in __getitem__                                                                               │
# │                                                                                                  │
# │    4116 │   │   else:                                                                            │
# │    4117 │   │   │   if is_iterator(key):                                                         │
# │    4118 │   │   │   │   key = list(key)                                                          │
# │ ❱  4119 │   │   │   indexer = self.columns._get_indexer_strict(key, "columns")[1]                │
# │    4120 │   │                                                                                    │
# │    4121 │   │   # take() does not accept boolean indexers                                        │
# │    4122 │   │   if getattr(indexer, "dtype", None) == bool:                                      │
# │                                                                                                  │
# │ /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages/pandas/core/indexes/ba │
# │ se.py:6212 in _get_indexer_strict                                                                │
# │                                                                                                  │
# │   6209 │   │   else:                                                                             │
# │   6210 │   │   │   keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)               │
# │   6211 │   │                                                                                     │
# │ ❱ 6212 │   │   self._raise_if_missing(keyarr, indexer, axis_name)                                │
# │   6213 │   │                                                                                     │
# │   6214 │   │   keyarr = self.take(indexer)                                                       │
# │   6215 │   │   if isinstance(key, Index):                                                        │
# │                                                                                                  │
# │ /opt/anaconda3/envs/recommendationsystem-env/lib/python3.12/site-packages/pandas/core/indexes/ba │
# │ se.py:6264 in _raise_if_missing                                                                  │
# │                                                                                                  │
# │   6261 │   │   │   │   raise KeyError(f"None of [{key}] are in the [{axis_name}]")               │
# │   6262 │   │   │                                                                                 │
# │   6263 │   │   │   not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())       │
# │ ❱ 6264 │   │   │   raise KeyError(f"{not_found} not in index")                                   │
# │   6265 │                                                                                         │
# │   6266 │   @overload                                                                             │
# │   6267 │   def _get_indexer_non_comparable(                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyError: "['rating_count_by_user'] not in index"

# %%
# Check status for both
for fg in [user_fg, item_fg]:
    status = fg.describe().get("FeatureGroupStatus")
    print(f"{fg.name} status: {status}")
    
    if status != "Created":
        print(f"Warning: {fg.name} is not ready yet. Please wait.")
